# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
from pylite.test import *
#from fastai import datasets

# %%
IMAGENETTE_160 = 'https://s3.amazonaws.com/fast-ai-imageclas/imagenette-160.tgz'

# %%
#dest = Path('C:\\Users\\yongy\\projects\\pylite\\nbs\\data\\imagenette-160.tgz')
#tarfile.open(dest, 'r:gz').extractall(dest.parent)

# %%
path = untar_data(IMAGENETTE_160)
#path = download_data(MNIST_URL, 'data/mnist', ext='.gz')

# %%
#export
import PIL,os,mimetypes
Path.ls = lambda x: list(x.iterdir())

# %%
path.ls()
# Out:
# [WindowsPath('C:/Users/yongy/projects/pylite/nbs/data/imagenette-160/train'),
#  WindowsPath('C:/Users/yongy/projects/pylite/nbs/data/imagenette-160/val')]

# %%
path_tench = path/'val'/'n01440764'

# %%
img_fn = path_tench.ls()[0]
img_fn
# Out:
# WindowsPath('C:/Users/yongy/projects/pylite/nbs/data/imagenette-160/val/n01440764/ILSVRC2012_val_00000293.JPEG')

# %%
img = PIL.Image.open(img_fn)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=213x160 at 0x1E5EE89B1D0>

# %%
all_fns = get_files(path, type='img', recurse=True)
len(all_fns)
# Out:
# 13394
